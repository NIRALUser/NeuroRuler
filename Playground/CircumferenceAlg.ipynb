# %%
# !pip3 install opencv-python
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("sample.jpg")

edges = cv2.Canny(img, 150, 500)
 
# Write image back to disk.
cv2.imwrite('result.jpg', edges)

plt.subplot(121)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(122)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection Result')
# Out:
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in /Users/hankhe/Library/Python/3.9/lib/python/site-packages (from opencv-python) (1.24.2)
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Text(0.5, 1.0, 'Edge Detection Result')

# %%
# Find contours.
contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

contour = contours[0]
circumference = cv2.arcLength(contour, True)

contour2 = contours[1]
circumference2 = cv2.arcLength(contour2, True)

# Print the circumference.
print(f'Circumference: {circumference}')
print(f'Circumference: {circumference2}')
# Out:
# Circumference: 830.482316493988
# Circumference: 828.1391699314117
